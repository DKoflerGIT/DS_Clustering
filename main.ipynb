# %%
import os, random, numpy as np
from functions import f_kMeans as km, f_createRandomDatapoints as crd, f_clusterPlot as plt

dpts = []
dpts = crd.createDatapoints(1000, 1) #kMeans works perfectly fine for 2+ dimensions good, for 1 dimension not always. plot works with 2 or 3 dimensions
kmeans = km.AssignClusters(dpts,2)
kmeans
#plt.plot(kmeans, 'k-Means clustering')

# c = []
# for k in kmeans:
#     if kmeans[k] not in c:
#         c.append(kmeans[k])
# print(np.sqrt((c[1][0] - c[0][0]) ** 2 + (c[1][1] - c[0][1]) ** 2))
# Out:
# {(4,): (25.0,),
#  (84,): (75.5,),
#  (34,): (25.0,),
#  (92,): (75.5,),
#  (26,): (25.0,),
#  (25,): (25.0,),
#  (14,): (25.0,),
#  (83,): (75.5,),
#  (3,): (25.0,),
#  (99,): (75.5,),
#  (95,): (75.5,),
#  (55,): (75.5,),
#  (24,): (25.0,),
#  (31,): (25.0,),
#  (48,): (25.0,),
#  (13,): (25.0,),
#  (44,): (25.0,),
#  (27,): (25.0,),
#  (9,): (25.0,),
#  (66,): (75.5,),
#  (70,): (75.5,),
#  (60,): (75.5,),
#  (56,): (75.5,),
#  (96,): (75.5,),
#  (16,): (25.0,),
#  (15,): (25.0,),
#  (72,): (75.5,),
#  (53,): (75.5,),
#  (36,): (25.0,),
#  (97,): (75.5,),
#  (69,): (75.5,),
#  (20,): (25.0,),
#  (22,): (25.0,),
#  (81,): (75.5,),
#  (18,): (25.0,),
#  (73,): (75.5,),
#  (88,): (75.5,),
#  (42,): (25.0,),
#  (37,): (25.0,),
#  (100,): (75.5,),
#  (85,): (75.5,),
#  (61,): (75.5,),
#  (39,): (25.0,),
#  (57,): (75.5,),
#  (1,): (25.0,),
#  (76,): (75.5,),
#  (17,): (25.0,),
#  (49,): (25.0,),
#  (19,): (25.0,),
#  (47,): (25.0,),
#  (29,): (25.0,),
#  (33,): (25.0,),
# ...
