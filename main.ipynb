# %%
from functions import kMeans as km

dpts = []
dpts = km.createRandomDatapoints(100, 2) #kMeans works for 2+ dimensions, for 1 dimension not always. plot works for 2 or 3 dimensions
clusterAmount = km.findOptimalClusterAmount(dpts)
kmeans = km.AssignClusters(dpts, clusterAmount, True)
km.plotClusters(kmeans)
# Out:
# Optimal number of clusters (change in WCSS < 10%): 4
